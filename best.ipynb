# %%
from google.colab import drive
import os
drive.mount('/gdrive') 

# !pip install pandas==0.23

# %load grabcutmod.py
import grabcutmod

# %load formatexcel.py
import formatexcel

# %load combined.py
import combined

total = len(os.listdir('/gdrive/My Drive/conclave gdrive final/Cropped Image Dataset/Cropped paper1/'))//2
for i in range(0,total):
  combined.prediction(i)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in find_user_code(self, target, raw, py_only, skip_encoding_cookie, search_ns)
#    3184         try:                                              # User namespace
# -> 3185             codeobj = eval(target, self.user_ns)
# ...

# %%
from google.colab import drive
import os
drive.mount('/gdrive') 

# %load grabcutmod.py
import grabcutmod

# %load formatexcel.py
import formatexcel

# %load combined.py
import combined

total = len(os.listdir('/gdrive/My Drive/conclave gdrive final/Cropped Image Dataset/Cropped paper1/'))//2
for i in range(0,total):
  combined.prediction(i)
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/conclave gdrive/Cropped Image Dataset/Cropped paper1/Register box 1.jpg Regbox
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-b8c5752625eb> in <module>()
#      14 total = len(os.listdir('/gdrive/My Drive/conclave gdrive final/Cropped Image Dataset/Cropped paper1/'))//2
#      15 for i in range(0,total):
# ---> 16   combined.prediction(i)
#
# /content/combined.py in prediction(i)
#     119     image, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
#     120
# --> 121     (contours,bounding_box) = sort_contours(contours,method="left-to-right")
#     122
#     123     #draw contours
#
# /content/combined.py in sort_contours(cnts, method)
# ...
